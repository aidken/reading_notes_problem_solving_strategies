# %% [markdown]
# # Chapter 1 The Invariance Principle
#
#   If there is repetition, look for what does not change!

# %% [markdown]
# ## Exercise 1.
#
# p. 2

# %%
import random

x_start = int( random.random() *100 )
y_start = int( random.random() *100 )

if y_start > x_start:
    temp = y_start
    y_start = x_start
    x_start = temp

f'{y_start=}, {x_start=}'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import random
#       4 x_start = int( random.random() *100 )
#
# File c:\Users\aidke\anaconda3\Lib\site-packages\matplotlib\pyplot.py:57
#      55 from cycler import cycler  # noqa: F401
#      56 import matplotlib
# ---> 57 import matplotlib.image
#      58 from matplotlib import _api
#      59 # Re-exported (import x as x) for typing.
#
# File c:\Users\aidke\anaconda3\Lib\site-packages\matplotlib\image.py:24
#      22 from matplotlib._image import *  # noqa: F401, F403
#      23 import matplotlib.artist as martist
# ---> 24 import matplotlib.colorizer as mcolorizer
#      25 from matplotlib.backend_bases import FigureCanvasBase
#      26 import matplotlib.colors as mcolors
#
# File c:\Users\aidke\anaconda3\Lib\site-packages\matplotlib\colorizer.py:30
#      27 from matplotlib import _api, colors, cbook, scale, artist
#      28 import matplotlib as mpl
# ---> 30 mpl._docstring.interpd.register(
#      31     colorizer_doc="""\
#      32 colorizer : `~matplotlib.colorizer.Colorizer` or None, default: None
#      33     The Colorizer object used to map color to data. If None, a Colorizer
#      34     object is created from a *norm* and *cmap*.""",
#      35     )
#      38 class Colorizer:
#      39     """
#      40     Data to color pipeline.
#      41
#    (...)
#      51         The normalization used to normalize the data
#      52     """
#
# AttributeError: '_ArtistPropertiesSubstitution' object has no attribute 'register'

# %%
def generate_next_x(x, y) -> float:
    return ( x + y ) / 2

def generate_next_y(x, y) -> float:
    return ( 2 * x * y ) / ( x + y )

x = [x_start]
y = [y_start]

for i in range(10):
    x.append( generate_next_x(x[-1], y[-1]) )
    y.append( generate_next_y(x[-1], y[-1]) )

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()        # Create a figure containing a single Axes.
ax.plot(x, y)                   # Plot some data on the Axes.
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 fig, ax = plt.subplots()        # Create a figure containing a single Axes.
#       4 ax.plot(x, y)
#
# File c:\Users\aidke\anaconda3\Lib\site-packages\matplotlib\pyplot.py:57
#      55 from cycler import cycler  # noqa: F401
#      56 import matplotlib
# ---> 57 import matplotlib.image
#      58 from matplotlib import _api
#      59 # Re-exported (import x as x) for typing.
#
# File c:\Users\aidke\anaconda3\Lib\site-packages\matplotlib\image.py:24
#      22 from matplotlib._image import *  # noqa: F401, F403
#      23 import matplotlib.artist as martist
# ---> 24 import matplotlib.colorizer as mcolorizer
#      25 from matplotlib.backend_bases import FigureCanvasBase
#      26 import matplotlib.colors as mcolors
#
# File c:\Users\aidke\anaconda3\Lib\site-packages\matplotlib\colorizer.py:30
#      27 from matplotlib import _api, colors, cbook, scale, artist
#      28 import matplotlib as mpl
# ---> 30 mpl._docstring.interpd.register(
#      31     colorizer_doc="""\
#      32 colorizer : `~matplotlib.colorizer.Colorizer` or None, default: None
#      33     The Colorizer object used to map color to data. If None, a Colorizer
#      34     object is created from a *norm* and *cmap*.""",
#      35     )
#      38 class Colorizer:
#      39     """
#      40     Data to color pipeline.
#      41
#    (...)
#      51         The normalization used to normalize the data
#      52     """
#
# AttributeError: '_ArtistPropertiesSubstitution' object has no attribute 'register'
